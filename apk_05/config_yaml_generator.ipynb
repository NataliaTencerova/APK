# %%
from yaml import dump as yaml_dump

# %%
# Save config

dict_cfg = {'ite_cfg': {
    'lecture_date': '15/10/2024',
    'username': 'kitt',
    'full_name': 'Martin Bulín'
}}

CONFIG_FILE = f'cfg_{dict_cfg["ite_cfg"]["username"]}.yaml'

with open(CONFIG_FILE, 'w') as fw:
    documents = yaml_dump(dict_cfg, fw, sort_keys=True, allow_unicode=True)
